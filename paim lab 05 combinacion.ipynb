# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
A = Image.open('./images/lab 05.png').convert('L')
A = np.asarray(A)
# Out:
# array([[ 0, 48, 45, ..., 70, 67, 67],
#        [ 0, 48, 47, ..., 72, 71, 71],
#        [ 0, 49, 49, ..., 74, 74, 76],
#        ...,
#        [ 0, 59, 59, ..., 26, 28, 29],
#        [ 0, 57, 49, ..., 26, 27, 28],
#        [ 0, 49, 47, ..., 25, 26, 27]], dtype=uint8)

# %%
print(A.min())
print(A.max())
# Out:
# 129
# 0

# %%
plt.hist(A.ravel(), 50)
# Out:
# (array([1.76010e+04, 9.43100e+03, 1.18290e+04, 3.67130e+04, 4.50540e+04,
#         1.02521e+05, 8.87650e+04, 4.00590e+04, 6.07890e+04, 4.55440e+04,
#         7.26020e+04, 5.03270e+04, 6.00570e+04, 4.73350e+04, 1.98660e+04,
#         1.83050e+04, 9.63000e+03, 1.14580e+04, 1.13820e+04, 8.50400e+03,
#         1.16870e+04, 7.94400e+03, 1.04680e+04, 5.64100e+03, 7.42400e+03,
#         7.63800e+03, 4.95000e+03, 7.66400e+03, 5.43000e+03, 7.64000e+03,
#         4.85600e+03, 6.67200e+03, 6.08700e+03, 3.81600e+03, 5.58000e+03,
#         3.15600e+03, 4.04000e+03, 2.92500e+03, 1.49000e+03, 1.70400e+03,
#         7.75000e+02, 9.19000e+02, 4.42000e+02, 5.41000e+02, 4.68000e+02,
#         2.07000e+02, 2.04000e+02, 5.30000e+01, 1.40000e+01, 3.00000e+00]),
#  array([  0.  ,   2.58,   5.16,   7.74,  10.32,  12.9 ,  15.48,  18.06,
#          20.64,  23.22,  25.8 ,  28.38,  30.96,  33.54,  36.12,  38.7 ,
#          41.28,  43.86,  46.44,  49.02,  51.6 ,  54.18,  56.76,  59.34,
# ...

# %%
plt.hist(A.ravel())
# Out:
# (array([120628., 337678., 250187.,  59279.,  43164.,  33322.,  27011.,
#          13315.,   3145.,    481.]),
#  array([  0. ,  12.9,  25.8,  38.7,  51.6,  64.5,  77.4,  90.3, 103.2,
#         116.1, 129. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(A.ravel(), 255)
# Out:
# (array([1.3197e+04, 2.5520e+03, 0.0000e+00, 1.8520e+03, 0.0000e+00,
#         2.2030e+03, 0.0000e+00, 3.0740e+03, 0.0000e+00, 4.1540e+03,
#         0.0000e+00, 4.9750e+03, 0.0000e+00, 6.8540e+03, 0.0000e+00,
#         8.5650e+03, 0.0000e+00, 1.1584e+04, 0.0000e+00, 1.6564e+04,
#         0.0000e+00, 2.0875e+04, 0.0000e+00, 2.4179e+04, 0.0000e+00,
#         2.9362e+04, 0.0000e+00, 3.4262e+04, 0.0000e+00, 3.8897e+04,
#         0.0000e+00, 3.4611e+04, 0.0000e+00, 3.0129e+04, 0.0000e+00,
#         2.4025e+04, 0.0000e+00, 2.0790e+04, 0.0000e+00, 1.9269e+04,
#         0.0000e+00, 1.8860e+04, 0.0000e+00, 2.0401e+04, 0.0000e+00,
#         2.1528e+04, 0.0000e+00, 2.3137e+04, 0.0000e+00, 2.2407e+04,
#         0.0000e+00, 2.3380e+04, 0.0000e+00, 2.5524e+04, 0.0000e+00,
#         2.3698e+04, 0.0000e+00, 2.4872e+04, 0.0000e+00, 2.5455e+04,
#         0.0000e+00, 2.1772e+04, 0.0000e+00, 1.9586e+04, 0.0000e+00,
#         1.8699e+04, 0.0000e+00, 1.6743e+04, 0.0000e+00, 1.6119e+04,
# ...
