# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
box = np.zeros((3, 3))

# %%
print(box)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]

# %%
plt.imshow(box)

# %%
white = np.ones((3, 3)) * 255
print(white)
# Out:
# [[255. 255. 255.]
#  [255. 255. 255.]
#  [255. 255. 255.]]

# %%
plt.imshow(white, cmap="gray", vmin=0, vmax=255)

# %%
plt.imshow(box, cmap="gray", vmin=0, vmax=255)

# %%
white = 255 * np.ones((3, 3))
white[0][2] = 0

plt.imshow(white, cmap="gray", vmin=0, vmax=255)

# %%
white = 255 * np.ones((3, 3))
white[2][0] = 0

plt.imshow(white, cmap="gray", vmin=0, vmax=255)

# %%
white = np.full((3, 3), 255)
white[2][0] = 0

plt.imshow(white, cmap="gray", vmin=0, vmax=255)

# %%
rd = 255 * np.random.random((10, 10))

plt.imshow(rd, cmap="coolwarm", vmin=0, vmax=255)

# %%
white =  255 * np.ones((10, 10, 3), dtype=np.int8)

white[0][0][1] = 0
white[0][0][2] = 0


white[1][1][0] = 0
white[1][1][2] = 0

white[2][2][0] = 0
white[2][2][1] = 0


white[0][0][0] = 108 
white[0][0][1] = 212
white[0][0][2] = 255


plt.imshow(white)
